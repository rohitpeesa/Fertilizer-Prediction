# %%
from sklearn import linear_model
import pandas as pd
regr = linear_model.LinearRegression()

# %%
ass1 = pd.read_csv('C://Users/Lenovo/Desktop/ML_EC.csv')

# %%
ass1.head(10)
# Out:
#    Moisture  Temperature  Humidity          Fertilizer
# 0        59           19        73                Urea
# 1        47           42        72  Potassium Chloride
# 2        52           18        49  Ammonium Phosphate
# 3        62           45        51  Ammonium Phosphate
# 4        58           18        63    Ammonium Nitrate
# 5        39           26        59  Ammonium Phosphate
# 6        53           19        40  Ammonium Phosphate
# 7        52           46        55    Ammonium Nitrate
# 8        47           31        52    Ammonium Nitrate
# 9        53           22        51  Ammonium Phosphate

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
ass1 = ass1.apply(le.fit_transform)

# %%
y = pd.DataFrame(ass1['Fertilizer'])

# %%
X = pd.DataFrame(ass1.drop(['Fertilizer'], axis=1))

# %%
train_set = X[1:]
train_labels = y[1:]

# %%
print(train_labels)
print(train_set)
# Out:
#        Fertilizer
# 1               2
# 2               1
# 3               1
# 4               0
# 5               1
# 6               1
# 7               0
# 8               0
# 9               1
# 10              3
# 11              0
# 12              2
# 13              1
# 14              0
# 15              3
# 16              2
# 17              0
# 18              3
# 19              0
# 20              0
# 21              0
# 22              2
# 23              3
# 24              2
# 25              1
# 26              1
# 27              3
# 28              1
# 29              3
# 30              1
# ...           ...
# 18709           3
# 18710           1
# 18711           3
# 18712           2
# 18713           2
# 18714           2
# 18715           2
# 18716           2
# 18717           2
# 18718           3
# 18719           0
# 18720           2
# 18721           0
# 18722           3
# 18723           0
# 18724           3
# 18725           1
# 18726           0
# ...

# %%
fit = regr.fit(train_set,train_labels)

# %%
print(train_labels)
print(train_set)
# Out:
#        Fertilizer
# 1               2
# 2               1
# 3               1
# 4               0
# 5               1
# 6               1
# 7               0
# 8               0
# 9               1
# 10              3
# 11              0
# 12              2
# 13              1
# 14              0
# 15              3
# 16              2
# 17              0
# 18              3
# 19              0
# 20              0
# 21              0
# 22              2
# 23              3
# 24              2
# 25              1
# 26              1
# 27              3
# 28              1
# 29              3
# 30              1
# ...           ...
# 18709           3
# 18710           1
# 18711           3
# 18712           2
# 18713           2
# 18714           2
# 18715           2
# 18716           2
# 18717           2
# 18718           3
# 18719           0
# 18720           2
# 18721           0
# 18722           3
# 18723           0
# 18724           3
# 18725           1
# 18726           0
# ...

# %%
prediction=regr.predict([[45,40,45]])

# %%
if(prediction<=1.46):
    r="Fertilizer Name=Urea-46.0/50 Kg.Bag,Firm Name=Nagarjuna Chemicals,Price(Unit in Rs./50 kg bag)=276.12"
elif((prediction>1.46) and (prediction<1.50)):
    r="Fertilizer Name=Am. Phos. Sulphate - 20:20:0:13 / 50 Kg. Bag,Firm Name=Best,Price(Unit in Rs./50 kg bag)=419.74"
elif(prediction>=1.51 and prediction<1.56):
    r="Fertilizer Name=Complex NPK-20:20:0:0/50 Kg.Bag,Firm Name=Florovit Agro,Price(Unit in Rs./50 kg bag)=466.93"
else:
    r="Fertilizer Name=Potassium Chloride - K.60.0(MOP) / 50 Kg. Bag,Firm Name=SQM,Price(Unit in Rs./50 kg bag)=872.00"
    
print(r)
# Out:
# Fertilizer Name=Complex NPK-20:20:0:0/50 Kg.Bag,Firm Name=Florovit Agro,Price(Unit in Rs./50 kg bag)=466.93

# %%
#This is a code just to mail the report 
import smtplib 
from email.mime.multipart import MIMEMultipart 
from email.mime.text import MIMEText 
from email.mime.base import MIMEBase 
from email import encoders 
sender='haha@gmail.com'
s_pwd='haha'
receiver='hello@gmail.com'

message1= """From:Classifier <Classifier>
To:receiver name <Rohit>
Subject: Fertilizer usage.

Hello sir, this is to inform use the best suitable fertilizer you have to use depending on the Temperature, Humidity and Moisture of surroundings where your plant is kept, we suggest you to use .
"""
message1=message1+r
message1=message1+".Hope this helps you"
mail=smtplib.SMTP('smtp.gmail.com',587)
mail.ehlo()
mail.starttls()
mail.login(sender,s_pwd)
mail.sendmail(sender,receiver,message1)
mail.close()

# %%
#This is a code to mail report as well as an attachment of image of fertilizer 
import smtplib 
from email.mime.multipart import MIMEMultipart 
from email.mime.text import MIMEText 
from email.mime.base import MIMEBase 
from email import encoders 
from email import encoders
fromaddr = "haha@gmail.com"
toaddr = "hello@gmail.com"
msg = MIMEMultipart()
msg['From'] = fromaddr
msg['To'] = toaddr
msg['Subject'] = "Fertilizer to be used"
body = "Hi, Rohit Bhargav Peesa! this is to inform use the best suitable fertilizer you have to use depending on the Temperature, Humidity and Moisture of surroundings where your plant is kept, we suggest you to use "
body=body+r
msg.attach(MIMEText(body, 'plain'))
if(r=="Fertilizer Name=Am. Phos. Sulphate - 20:20:0:13 / 50 Kg. Bag,Firm Name=Best,Price(Unit in Rs./50 kg bag)=419.74"):
    filename ="Am.Phosphate fertilizer.jpg"
    attachment = open('C:/Users/Lenovo/Desktop/Am.Phosphate fertilizer.jpg', "rb")
elif(r=="Fertilizer Name=Urea-46.0/50 Kg.Bag,Firm Name=Nagarjuna Chemicals,Price(Unit in Rs./50 kg bag)=276.12"):
    filename ="Urea-Bag.jpg"
    attachment = open('C:/Users/Lenovo/Desktop/Urea-Bag.jpg', "rb")
elif(r=="Fertilizer Name=Potassium Chloride - K.60.0(MOP) / 50 Kg. Bag,Firm Name=SQM,Price(Unit in Rs./50 kg bag)=872.00"):
    filename ="pot chloride .jpg"
    attachment = open('C:/Users/Lenovo/Desktop/pot chloride .jpg', "rb")
else:
    filename ="Florovit_AGRO_COMPLEX_25_kg_small_1.jpg"
    attachment = open('C:/Users/Lenovo/Desktop/Florovit_AGRO_COMPLEX_25_kg_small_1.jpg', "rb")
part = MIMEBase('application', 'octet-stream')
part.set_payload((attachment).read())
encoders.encode_base64(part)
part.add_header('Content-Disposition', "attachment; filename= %s" % filename)
 
msg.attach(part)
 
server = smtplib.SMTP('smtp.gmail.com', 587)
server.starttls()
server.login(fromaddr,"haha")
text = msg.as_string()
server.sendmail(fromaddr, toaddr, text)
server.quit()
# Out:
# (221, b'2.0.0 closing connection t15-v6sm5965103pfj.7 - gsmtp')
